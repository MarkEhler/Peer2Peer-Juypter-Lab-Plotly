# %% [markdown]
# # Markdown
#
# ## Markdown
#
# ### Markdown

# %% [markdown]
# <h1><center> Markdown </h1>
#     <h2><center> Markdown </h2>
#         <h3><center> Markdown </h3>

# %% [markdown]
# <h1 align="right"> Markdown </h1>
#     <h2 align="right"> Markdown </h2>
#         <h3 align="right"> Use It </h3>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
#import plotly.graph
#import cufflinks

# %% [markdown]
# ## Introducing:
#
# https://www.kaggle.com/abcsds/pokemon

# %%
# !dir /b
# Out:
# .ipynb_checkpoints
# Fall.gif
# Find_a_Visualization.jpg
# Jupyter and Visualization - Codealong.ipynb
# Pokemon.csv
# Time Series Codealong.ipynb

# %%
df = pd.read_csv("Pokemon.csv")


Gen1 = df.loc[0:161]

# %%
ds = df.drop(['Type 2', '#', 'Legendary'], axis = 1)
#make dummies Type, Gen
ts = df.drop(['Type 2', 'Legendary'], axis = 1)
#groupby(# for every # round down to 5) % and //

#df['Generation Subset'] = df['Generation'].apply(fx) %  //

#write a fx to with conditional statements

#this is a reasonable task to need to know

# %% [markdown]
# <center><img src="Find_a_Visualization.jpg"
# style = "float: center; height:500px" /><center>

# %% [markdown]
# ## solving for 1 to 2 variables in comparison
#
# Hint: (among categories) (with small sample size) (over time)

# %% [markdown]
# ### Histograms

# %%
import plotly.graph_objs as go
import plotly.plotly as py
from plotly.offline import iplot, init_notebook_mode

import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
Gen1['Total'].iplot(kind='hist', bins=40, xTitle='Power Level', linecolor='blue', yTitle='# of Mons', title="Original 150 Power Distribution")

# %%
df[['Attack', 'Speed']].iplot(
    kind='hist',
    histnorm='percent',
    barmode='overlay',
    xTitle='Power Level',
    yTitle='(%) of Pokemon',
    title='Attack and Speed Distributions of Pokemon')
#cufflinks allows us to add columns much the same way .plot() does for us with matplotlib

# %% [markdown]
# For a bar plot, we need to apply some sort of aggregation function and then plot. For example, we can show the count of articles in each publication with the following.

# %% [markdown]
# Boxplot with Different Categories
#
#
# If we have different categories that we want to plot, we need to use a pivot. This transforms each unique value in a column into a separate column.

# %%
df2 = df.pivot(
    columns='Type 1', values='Defense')
df2.head()
# Out:
# Type 1  Bug  Dragon  Electric  Fairy  Fighting  Fire  Ghost  Grass  Ground  \
# 0       NaN     NaN       NaN    NaN       NaN   NaN    NaN   49.0     NaN
# 1       NaN     NaN       NaN    NaN       NaN   NaN    NaN   63.0     NaN
# 2       NaN     NaN       NaN    NaN       NaN   NaN    NaN   83.0     NaN
# 3       NaN     NaN       NaN    NaN       NaN   NaN    NaN  123.0     NaN
# 4       NaN     NaN       NaN    NaN       NaN  43.0    NaN    NaN     NaN
#
# Type 1  Ice  Normal  Poison  Psychic  Rock  Water
# 0       NaN     NaN     NaN      NaN   NaN    NaN
# 1       NaN     NaN     NaN      NaN   NaN    NaN
# 2       NaN     NaN     NaN      NaN   NaN    NaN
# 3       NaN     NaN     NaN      NaN   NaN    NaN
# 4       NaN     NaN     NaN      NaN   NaN    NaN

# %%
df2.iplot(
        kind='box',
        layout=dict(
            height=600,
            yaxis=dict(title='Defense'),
            title='Defense by Type',
            margin=dict(b=140)))

# %% [markdown]
# ## solving for relationship between 2 variables
#
# Hint: Widely used

# %% [markdown]
# ## solving for distribution of two variables
#
# Hint: More than one answer

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# ## Visualizing a time dependant variable
#
# Hint: The answer is in the question

# %% [markdown]
# ### Line chart
#
# (also Time Series)

# %% [markdown]
# |  Time  | Wind Direction | Tempurature | Wind Speed | Humidity |
# |:-------:|:---------:|:------:|:--------:|:--------:|
# | Minute 1 |     0.94688      |    78.04    |     3     |     0.42     |
# | Minute 2 |     0.74481      |    77.32    |     2     |    0.40      |
# | Minute 3 |    0.88991      |   78.64     |    11      |     0.34     |

# %%
df.groupby('Generation').max()
# Out:
#               #              Name Type 1  Total   HP  Attack  Defense  \
# Generation
# 1           151             Zubat  Water    780  250     190      180
# 2           251             Yanma  Water    700  255     185      230
# 3           386         Zigzagoon  Water    780  170     180      230
# 4           493           Yanmega  Water    720  150     170      168
# 5           649          Zweilous  Water    700  165     170      145
# 6           721  Zygarde50% Forme  Water    700  126     160      184
#
#             Sp. Atk  Sp. Def  Speed  Legendary
# Generation
# 1               194      130    150       True
# 2               165      230    130       True
# 3               180      200    180       True
# 4               150      150    135       True
# 5               170      135    145       True
# 6               170      154    126       True

# %%
df.groupby('Generation').Total.mean().iplot(
    mode='markers',
    opacity=0.8,
    size=8,
    symbol=1,
    xTitle='Generation',
    yTitle='Power Level',
    title='Avg Pokemon Power Levels Over the Generations')

# %%
#text =  #.max() up until that point
#lines+
#text='text',

df['text'] = [
    f'<span style="color:blue">{m}<span><br>words'
    for m in df['#'].max()]
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-7df7c46d59d2> in <module>
#       5 df['text'] = [
#       6     f'<span style="color:blue">{m}<span><br>words'
# ----> 7     for m in df['#'].max()]
#       8 df.head()
#
# TypeError: 'numpy.int64' object is not iterable

# %%
df['text'] = [
    f'<span style="color:blue">{m}<span><br>words: {w:.0f}'
    for m, w in zip(df.index.month_name(),
                    df['word_count'])
]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-4174d80f96bd> in <module>
#       1 df['text'] = [
#       2     f'<span style="color:blue">{m}<span><br>words: {w:.0f}'
# ----> 3     for m, w in zip(df.index.month_name(),
#       4                     df['word_count'])
#       5 ]
#
# AttributeError: 'RangeIndex' object has no attribute 'month_name'

# %% [markdown]
# ### 3 Numeric Variables

# %%
text = [
    f'{t}'
    for t in(df['Name'])
]

Gen1.iplot(
    x='Defense',
    y='Sp. Def',
    opacity=0.8,
    size=df['HP'],
    text=text,
    mode='markers',
    theme='pearl',
    layout=dict(
        xaxis=dict(type='log', title='Defense'),
        yaxis=dict(title='Special Defense'),
        title='Defensive Stats of Gen 1 Pokemon'))

# %% [markdown]
# ### Correlation
# <ul>
#
# <li>Find the mean of all the x-values and y-values.</li>
# <li>Find the standard deviation of all the x-values (call it sx) and the standard deviation of all the y-values (call it sy). </li>
# <li>For each of the n pairs (x, y) in the data set, take.</li>
# <li>Add up the n results from Step 3.</li>
# <li>Divide the sum by sx ∗ sy.</li>
#
# $$Correlation = \frac{\text{(x - mean_x) * (y - mean_y)}}{\text{sx * sy}}$$

# %% [markdown]
# ### Heat Map

# %%
import plotly.figure_factory as ff

corrs = ds.iloc[:,:-1].corr()

figure = ff.create_annotated_heatmap(
    z=corrs.values,
    x=list(corrs.columns),
    y=list(corrs.index),
    colorscale='Portland',
    annotation_text=corrs.round(2).values,
    showscale=True, reversescale=True)

figure.layout.margin = dict(l=200, t=200)
figure.layout.height = 800
figure.layout.width = 1000

iplot(figure)

# %%
### Have Pie

#Legendary

# %%
import plotly.plotly as py
import plotly.graph_objs as go

labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500,2500,1053,500]
colors = ['#FEBFB3', '#E1396C', '#96D38C', '#D0F9B1']

trace = go.Pie(labels=labels, values=values,
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=20),
               marker=dict(colors=colors, 
                           line=dict(color='#000000', width=2)))

py.iplot([trace], filename='styled_pie_chart')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ...

# %% [markdown]
# <img src="Fall.gif"
# style = "float: right; height:500px" />

# %% [markdown]
# "jupyter labextension install my-extension"
#
# jupyter labextension list

# %% [markdown]
# !dir /b "bare" /s "subs" %who function string %load %run %writefile

# %% [markdown]
# ![chart](Find_a_Visualization.jpg)
# <br><br><br>
# ![fall](Fall.gif)

# %% [markdown]
# Ipython Documentation: https://ipython.readthedocs.io/en/stable/interactive/magics.html
#
# Using Interact: https://ipywidgets.readthedocs.io/en/stable/examples/Using%20Interact.html
#
# Plotly extension for Jupyter Lab:  https://github.com/jupyterlab/jupyter-renderers/tree/master/packages/plotly-extension
